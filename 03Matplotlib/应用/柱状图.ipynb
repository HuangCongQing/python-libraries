# %% [markdown]
# # 多列数据对比
# https://blog.csdn.net/weixin_44293949/article/details/114590319?

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# plt.rcParams['font.sans-serif']=['SimHei'] # 解决中文乱码
# 创建一个点数为 8 x 6 的窗口, 并设置分辨率为 250像素/每英寸
# plt.figure(figsize=(10, 8), dpi=230)

labels = ['RS-LiDAR-16', 'RS-BPearl']
a = [28.72, 29.20]
b = [42.51, 87.71]
c = [25.53, 25.88]
# d = [59.3, 81.5]
# e = [89, 90]    


x = np.arange(len(labels))  # 标签位置
width = 0.1  # 柱状图的宽度，可以根据自己的需求和审美来改

fig, ax = plt.subplots()
rects1 = ax.bar(x - width*2, a, width, label='Algorithm1')
rects2 = ax.bar(x - width+0.01, b, width, label='Algorithm2')
rects3 = ax.bar(x + 0.02, c, width, label='VSSeg(Ours)')
# rects4 = ax.bar(x + width+ 0.03, d, width, label='d')
# rects5 = ax.bar(x + width*2 + 0.04, e, width, label='e')


# 为y轴、标题和x轴等添加一些文本。
ax.set_ylabel('Time(ms)', fontsize=12)
ax.set_xlabel('LiDAR Type', fontsize=12)
# ax.set_title('这里是标题')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """在*rects*中的每个柱状条上方附加一个文本标签，显示其高度"""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3点垂直偏移
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
# autolabel(rects4)
# autolabel(rects5)

plt.style.use('seaborn-darkgrid') # 设置画图的风格 
fig.tight_layout()
plt.savefig('time_diff.jpg', dpi=300)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['font.sans-serif']=['SimHei'] # 解决中文乱码
# 创建一个点数为 8 x 6 的窗口, 并设置分辨率为 250像素/每英寸
# plt.figure(figsize=(10, 8), dpi=230)

labels = ['RS-LiDAR-16', 'RS-BPearl']
a = [28.72, 29.20]
b = [42.51, 87.71]
c = [25.53, 25.88]
# d = [59.3, 81.5]
# e = [89, 90]    


x = np.arange(len(labels))  # 标签位置
width = 0.1  # 柱状图的宽度，可以根据自己的需求和审美来改

fig, ax = plt.subplots()
rects1 = ax.bar(x - width*2, a, width, label='Algorithm1')
rects2 = ax.bar(x - width+0.01, b, width, label='Algorithm2')
rects3 = ax.bar(x + 0.02, c, width, label='Proposal(Ours)')
# rects4 = ax.bar(x + width+ 0.03, d, width, label='d')
# rects5 = ax.bar(x + width*2 + 0.04, e, width, label='e')


# 为y轴、标题和x轴等添加一些文本。
ax.set_ylabel('Time(ms)', fontsize=12)
ax.set_xlabel('LiDAR Type', fontsize=12)
# ax.set_title('这里是标题')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """在*rects*中的每个柱状条上方附加一个文本标签，显示其高度"""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3点垂直偏移
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
# autolabel(rects4)
# autolabel(rects5)

plt.style.use('seaborn-darkgrid') # 设置画图的风格 
fig.tight_layout()
plt.savefig('time_diff_cn.jpg', dpi=300)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


def auto_label(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height), # put the detail data
                    xy=(rect.get_x() + rect.get_width() / 2, height), # get the center location.
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


def auto_text(rects):
    for rect in rects:
        ax.text(rect.get_x(), rect.get_height(), rect.get_height(), ha='left', va='bottom')


labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
means = [25, 32, 34, 20, 25]

index = np.arange(len(labels))
width = 0.2

fig, ax = plt.subplots()
rect1 = ax.bar(index - width / 2, men_means, color ='lightcoral', width=width, label ='Men')
rect2 = ax.bar(index + width / 2, women_means, color ='springgreen', width=width, label ='Women')
# rect3 = ax.bar(index + width / 2, means, color ='springgreen', width=width, label ='means')

ax.set_title('Scores by gender')
ax.set_xticks(ticks=index)
ax.set_xticklabels(labels)
ax.set_ylabel('Scores')

ax.set_ylim(0, 50)
# auto_label(rect1)
# auto_label(rect2)
auto_text(rect1)
auto_text(rect2)
# auto_text(rect3)

ax.legend(loc='upper right', frameon=False)
fig.tight_layout()
plt.savefig('2.jpg', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from pylab import *  # 支持中文
mpl.rcParams['font.sans-serif'] = ['SimHei']
# 创建一个点数为 8 x 6 的窗口, 并设置分辨率为 250像素/每英寸
plt.figure(figsize=(10, 8), dpi=230)

# 再创建一个规格为 1 x 1 的子图
plt.subplot(1, 1, 1)

# 柱子总数
N = 11
# 包含每个柱子对应值的序列
values = (1941, 391, 22, 328, 1387, 2928, 1063, 394, 198,117,343)

# 包含每个柱子下标的序列
index = np.arange(N)

# 柱子的宽度
width = 0.3

# 绘制柱状图, 每根柱子的颜色为紫罗兰色
p2 = plt.bar(index, values, width, color="#87CEFA")

# 设置横轴标签
plt.xlabel('样本字符出现次数',fontsize=12)
# 设置纵轴标签
plt.ylabel('出现对应次数的汉字数量', fontsize=12)

# 添加标题
# plt.title('文本检测对比图')

# 添加纵横轴的刻度
plt.xticks(index, ('<10', '<20', '<30',
                   '<40', ' <50', '<100', '<200', '<300', ' <400', '<500', '>500'))
plt.yticks(np.arange(0, 4001, 1000))

# 添加图例
plt.legend(loc="upper right")
for a, b in zip(index, values):
    plt.text(a, b, b, ha='center', va='bottom', fontsize=10)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# 显示数据集分类
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline  


# 创建一个点数为 8 x 6 的窗口, 并设置分辨率为 250像素/每英寸
plt.figure(figsize=(10, 6), dpi=230)

x = np.array(['Truck','Auxiliary','Car','Excavator','Widebody','Pedestrian'])
y = np.array([2432, 364, 362, 357, 299, 130])

plt.bar(x, y,  color = ["#4CAF50","red","hotpink","#556B2F","green","blue"])

#使用text显示数值  
for a,b in zip(x,y):  
 plt.text(a, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=11)

plt.xlabel("Label")  #设置X轴Y轴名称  
plt.ylabel("Number")  
# plt.title("bar chart")
plt.style.use('seaborn-darkgrid') # 设置画图的风格 
# 保存图片
fig=plt.gcf()
fig.savefig('./mine.jpg')

plt.show()

# %% [markdown]
# ## 多张图片可视化（all  test val test）
# * all_class: [2432, 364, 362, 357, 299, 130]
# * train_class: [1928, 293, 288, 291, 225, 90]
# * val_class: [239, 41, 38, 23, 43, 16]
# * test_class: [265, 30, 36, 43, 31, 24]

# %%
import matplotlib.pyplot as plt
import numpy as np
from pylab import *  # 支持中文
mpl.rcParams['font.sans-serif'] = ['SimHei']
# 创建一个点数为 8 x 6 的窗口, 并设置分辨率为 250像素/每英寸
plt.figure(figsize=(14, 10), dpi=230)


#plot 1:===============================
plt.subplot(2, 2, 1)
x = np.array(['Truck','Auxiliary','Car','Excavator','Widebody','Pedestrian'])
y = np.array([2432, 364, 362, 357, 299, 130])

plt.bar(x, y,  color = ["#4CAF50","red","hotpink","#556B2F","green","blue"])

#使用text显示数值  
for a,b in zip(x,y):  
 plt.text(a, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=11)

plt.xlabel("Label")  #设置X轴Y轴名称  
plt.ylabel("Number")  
plt.title("all set", fontsize=14)
plt.style.use('seaborn-darkgrid') # 设置画图的风格 


#plot 2:===============================
plt.subplot(2, 2, 2)
x = np.array(['Truck','Auxiliary','Car','Excavator','Widebody','Pedestrian'])
y = np.array([1928, 293, 288, 291, 225, 90])

plt.bar(x, y,  color = ["#4CAF50","red","hotpink","#556B2F","green","blue"])

#使用text显示数值  
for a,b in zip(x,y):  
 plt.text(a, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=11)

plt.xlabel("Label")  #设置X轴Y轴名称  
plt.ylabel("Number")  
plt.title("train set", fontsize=14) # # fontproperties 设置中文显示，fontsize 设置字体大小
plt.style.use('seaborn-darkgrid') # 设置画图的风格 

#plot 3:===============================
plt.subplot(2, 2, 3)
x = np.array(['Truck','Auxiliary','Car','Excavator','Widebody','Pedestrian'])
y = np.array([239, 41, 38, 23, 43, 16])

plt.bar(x, y,  color = ["#4CAF50","red","hotpink","#556B2F","green","blue"])

#使用text显示数值  
for a,b in zip(x,y):  
 plt.text(a, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=11)

plt.xlabel("Label")  #设置X轴Y轴名称  
plt.ylabel("Number")  
plt.title("val set", fontsize=14)
plt.style.use('seaborn-darkgrid') # 设置画图的风格 

#plot 4:===============================
plt.subplot(2, 2, 4)
x = np.array(['Truck','Auxiliary','Car','Excavator','Widebody','Pedestrian'])
y = np.array([265, 30, 36, 43, 31, 24])

plt.bar(x, y,  color = ["#4CAF50","red","hotpink","#556B2F","green","blue"])

#使用text显示数值  
for a,b in zip(x,y):  
 plt.text(a, b+0.05, '%.0f' % b, ha='center', va= 'bottom',fontsize=11)

plt.xlabel("Label")  #设置X轴Y轴名称  
plt.ylabel("Number")  
plt.title("test set", fontsize=14)
plt.style.use('seaborn-darkgrid') # 设置画图的风格 


# ===============================

# 保存图片
fig=plt.gcf()
fig.savefig('./dataset.jpg')

plt.show()
